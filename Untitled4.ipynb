# %% [markdown]
# <a href="https://colab.research.google.com/github/kimyeonju7295/lovely/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1번
# 기호주의
# - 문제와 논리, 탐색을 사람이 이해할 수 있는 기호로 표현하여 답을 찾으려고 하는 인공지능 방식
# - 인간의 지식을 기호화하고 그 기호 간의 관계를 일일이 컴퓨터에 입력하여 학습시키면 컴퓨터도 인간과 비슷한 입력을 얻었을 때 출력 또한 비슷하게 낼 것 이라는 주장을 하였고 그의 관점은 기호주의 인공지능의 시작이 되었다.
# - MYCIN : 감염성 질환에 대한 처방을 제공하는 목적을 만들어 졌으며 환자의 증상과 의료 진단 결과를 통해 환자를 진단하는 기능을 가지고 있으며 500개의 규칙을 사용하여 당시 의료 전문가 수준의 의료진단 기능을 수행했다.
#
# 연결주의
# - 퍼셉트론처럼 연결된 요소가 학습을 통해 해법을 스스로 찾도록 만들려는 방식
# - 다층신경망의 학습방법 오류 역전파 알고리즘의 발견
# - 인간의 두뇌에서 어떻게 생각하는지를 모방하여 컴퓨터를 학습시키는 방법으로 마치 두뇌에서 여러 신경세포를 통해 정보를 다루듯 하나의 개념이 여러곳에 흩어져서 표현된다는 것을 중점으로 두는 과학 분야의 접근법
# - Deep learning으로 발전
# - 퍼셉트론 : 연결주의를 주장한 프랭크 로젯블랫이 고안한 초기형태의 인공 신경망으로 인지능력과 뇌 신경세포를 결합한 단어이고 여기서 언급하는 인공신경망 시스템은 동물의 신경게를 본따 만들었기 때문에 개념과 그 형태가 굉장히 비슷한 부분이 많습니다.
#
# #2번
# 지도학습
# - 입력(문제)-출력(답)의 데이터들로 부터 새로운 입력에 대한 출력을 결정할 수 있는 패턴 추출
# - 분류
# - 회귀
#
# 비지도학습
# - 출력에 대한 정보가 없는 데이터로부터 필요한 패턴 추출
# - 군집
# - 차원축소
#
# 강화학습
# - 출력에 대한 정확한 정보를 제공하지는 않지만, 평가정보는 주어지는 문제에 대해 각 상태에서의 행동을 결정
#
# #3번
# 기계학습은 훈련할 대규모 데이터 세트가 필요하며, 이러한 데이터 세트는 포괄적/편향적이어야 하며 품질이 우수해야 한다. 또한 새로운 데이터가 생선될 때까지 기다려야 하는 경우도 있다.
# 또 복잡한 데이터들이 있고 이들 데이터에 기반하여 결정을 내려야 하는 분야이다. 데이터 특징이 계속 바뀌고 프로그램을 계속해서 변경해야하는 문제점이 있다.
#
# #4번
# 1. training용 데이터로 모델을 훈련시킬 때 발생하는 오차로, 모델이 데이터를 반복 학습하는 횟수가 늘어날수록 모델의 복잡한 정도도 따라서 늘어남 그래서 training error는 줄어듦
# 2. 예측값들과 정답이 대체로 멀리 떨어져 있으면 결과의 편향(bias)이 높고 예측값들이 자기들끼리 대체로 멀리 흩어져 있으면 결과의 분산(variance)이 높다. 따라서 이 표는 정답과 예측은 거의 같고 모델의 출력값들은 흩어져 있다.
